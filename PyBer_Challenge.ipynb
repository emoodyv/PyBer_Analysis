# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "city_data.csv"
ride_data_to_load = "ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]
urban_cities_df = pyber_data_df[pyber_data_df["type"] == "Urban"]

#  1. Get the total rides for each city type
urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"].sum()
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"].sum()
rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"].sum()

# %%
# 2. Get the total drivers for each city type
urban_driver_count = city_data_df[city_data_df['type'] == 'Urban'].groupby(["city"]).sum()["driver_count"].sum()
suburban_driver_count = city_data_df[city_data_df['type'] == 'Suburban'].groupby(["city"]).sum()["driver_count"].sum()
rural_driver_count = city_data_df[city_data_df['type'] == 'Rural'].groupby(["city"]).sum()["driver_count"].sum()

# %%
#  3. Get the total amount of fares for each city type
urban_fare_total = urban_cities_df.groupby(["city"]).sum()["fare"].sum()
suburban_fare_total = suburban_cities_df.groupby(["city"]).sum()["fare"].sum()
rural_fare_total = rural_cities_df.groupby(["city"]).sum()["fare"].sum()

# %%
#  4. Get the average fare per ride for each city type. 
urban_avg_fare_ride = urban_fare_total / urban_ride_count
suburban_avg_fare_ride = suburban_fare_total / suburban_ride_count
rural_avg_fare_ride = rural_fare_total / rural_ride_count

# %%
# 5. Get the average fare per driver for each city type. 
urban_avg_fare_driver = urban_fare_total / urban_driver_count
suburban_avg_fare_driver = suburban_fare_total / suburban_driver_count
rural_avg_fare_driver = rural_fare_total / rural_driver_count

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.DataFrame(data={'Total Rides': [rural_ride_count, suburban_ride_count, urban_ride_count], 
                                'Total Drivers': [rural_driver_count, suburban_driver_count, urban_driver_count],
                                'Total Fares': [rural_fare_total, suburban_fare_total, urban_fare_total],
                                'Average Fare per Ride': [rural_avg_fare_ride, suburban_avg_fare_ride, urban_avg_fare_ride],
                                'Average Fare per Driver': [rural_avg_fare_driver, suburban_avg_fare_driver, urban_avg_fare_driver]},
                                index=['Rural', 'Suburban', 'Urban'])

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.
pyber_summary_df['Total Rides'] = pyber_summary_df['Total Rides'].map('{:,}'.format)
pyber_summary_df['Total Drivers'] = pyber_summary_df['Total Drivers'].map('{:,}'.format)
pyber_summary_df['Total Fares'] = pyber_summary_df['Total Fares'].map('${:,.2f}'.format)
pyber_summary_df['Average Fare per Ride'] = pyber_summary_df['Average Fare per Ride'].map('${:,.2f}'.format)
pyber_summary_df['Average Fare per Driver'] = pyber_summary_df['Average Fare per Driver'].map('${:,.2f}'.format)
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
date_df = pyber_data_df[['date', 'type', 'fare']]
date_df
# Out:
#                      date   type   fare
# 0     2019-01-14 10:14:22  Urban  13.83
# 1     2019-03-04 18:24:09  Urban  30.24
# 2     2019-02-24 04:29:00  Urban  33.44
# 3     2019-02-10 23:22:03  Urban  23.44
# 4     2019-03-06 04:28:35  Urban  34.58
# ...                   ...    ...    ...
# 2370  2019-04-29 17:04:39  Rural  13.38
# 2371  2019-01-30 00:05:47  Rural  20.76
# 2372  2019-02-10 21:03:50  Rural  11.11
# 2373  2019-05-07 19:22:15  Rural  44.94
# 2374  2019-04-25 10:20:13  Rural  55.84
#
# [2375 rows x 3 columns]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
date_df.reset_index()
# Out:
#       index                 date   type   fare
# 0         0  2019-01-14 10:14:22  Urban  13.83
# 1         1  2019-03-04 18:24:09  Urban  30.24
# 2         2  2019-02-24 04:29:00  Urban  33.44
# 3         3  2019-02-10 23:22:03  Urban  23.44
# 4         4  2019-03-06 04:28:35  Urban  34.58
# ...     ...                  ...    ...    ...
# 2370   2370  2019-04-29 17:04:39  Rural  13.38
# 2371   2371  2019-01-30 00:05:47  Rural  20.76
# 2372   2372  2019-02-10 21:03:50  Rural  11.11
# 2373   2373  2019-05-07 19:22:15  Rural  44.94
# 2374   2374  2019-04-25 10:20:13  Rural  55.84
#
# [2375 rows x 4 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
date_df = date_df.pivot(index='date', columns='type')
date_df
# Out:
#                      fare
# type                Rural Suburban  Urban
# date
# 2019-01-01 00:08:16   NaN      NaN  37.91
# 2019-01-01 00:46:46   NaN    47.74    NaN
# 2019-01-01 02:07:24   NaN    24.07    NaN
# 2019-01-01 03:46:50   NaN      NaN   7.57
# 2019-01-01 05:23:21   NaN      NaN  10.75
# ...                   ...      ...    ...
# 2019-05-08 04:20:00   NaN      NaN  21.99
# 2019-05-08 04:39:49   NaN      NaN  18.45
# 2019-05-08 07:29:01   NaN      NaN  18.55
# 2019-05-08 11:38:35   NaN      NaN  19.77
# 2019-05-08 13:10:18   NaN      NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
date_jan_apr_df = date_df.loc["2019-01-01":"2019-04-29"]
date_jan_apr_df
# Out:
#               fare
# type         Rural Suburban    Urban
# date
# 2019-01-06  187.92   721.60  1661.68
# 2019-01-13   67.65  1105.13  2050.43
# 2019-01-20  306.00  1218.20  1939.02
# 2019-01-27  179.69  1203.28  2129.51
# 2019-02-03  333.08  1042.79  2086.94
# 2019-02-10  115.80   974.34  2162.64
# 2019-02-17   95.82  1045.50  2235.07
# 2019-02-24  419.06  1412.74  2466.29
# 2019-03-03  175.14   858.46  2218.20
# 2019-03-10  303.94   925.27  2470.93
# 2019-03-17  163.39   906.20  2044.42
# 2019-03-24  189.76  1122.20  2368.37
# 2019-03-31  199.42  1045.06  1942.77
# 2019-04-07  501.24  1010.73  2356.70
# 2019-04-14  269.79   784.82  2390.72
# 2019-04-21  214.14  1149.27  2303.80
# 2019-04-28  191.85  1357.75  2238.29

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
date_jan_apr_df.index = pd.to_datetime(date_jan_apr_df.index)
date_jan_apr_df
# Out:
#               fare
# type         Rural Suburban    Urban
# date
# 2019-01-06  187.92   721.60  1661.68
# 2019-01-13   67.65  1105.13  2050.43
# 2019-01-20  306.00  1218.20  1939.02
# 2019-01-27  179.69  1203.28  2129.51
# 2019-02-03  333.08  1042.79  2086.94
# 2019-02-10  115.80   974.34  2162.64
# 2019-02-17   95.82  1045.50  2235.07
# 2019-02-24  419.06  1412.74  2466.29
# 2019-03-03  175.14   858.46  2218.20
# 2019-03-10  303.94   925.27  2470.93
# 2019-03-17  163.39   906.20  2044.42
# 2019-03-24  189.76  1122.20  2368.37
# 2019-03-31  199.42  1045.06  1942.77
# 2019-04-07  501.24  1010.73  2356.70
# 2019-04-14  269.79   784.82  2390.72
# 2019-04-21  214.14  1149.27  2303.80
# 2019-04-28  191.85  1357.75  2238.29

# %%
# 7. Check that the datatype for the index is datetime using df.info()
date_jan_apr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17 entries, 2019-01-06 to 2019-04-28
# Freq: W-SUN
# Data columns (total 3 columns):
# (fare, Rural)       17 non-null float64
# (fare, Suburban)    17 non-null float64
# (fare, Urban)       17 non-null float64
# dtypes: float64(3)
# memory usage: 544.0 bytes

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
date_jan_apr_df = date_jan_apr_df.resample('W').sum()
date_jan_apr_df
# Out:
#               fare
# type         Rural Suburban    Urban
# date
# 2019-01-06  187.92   721.60  1661.68
# 2019-01-13   67.65  1105.13  2050.43
# 2019-01-20  306.00  1218.20  1939.02
# 2019-01-27  179.69  1203.28  2129.51
# 2019-02-03  333.08  1042.79  2086.94
# 2019-02-10  115.80   974.34  2162.64
# 2019-02-17   95.82  1045.50  2235.07
# 2019-02-24  419.06  1412.74  2466.29
# 2019-03-03  175.14   858.46  2218.20
# 2019-03-10  303.94   925.27  2470.93
# 2019-03-17  163.39   906.20  2044.42
# 2019-03-24  189.76  1122.20  2368.37
# 2019-03-31  199.42  1045.06  1942.77
# 2019-04-07  501.24  1010.73  2356.70
# 2019-04-14  269.79   784.82  2390.72
# 2019-04-21  214.14  1149.27  2303.80
# 2019-04-28  191.85  1357.75  2238.29

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

plt.plot(date_jan_apr_df)

plt.title('Total Fare by City Type')
plt.ylabel('Fare ($USD)')

plt.savefig('PyBer_fare_summary.png', bbox_inches='tight', quality=95)
